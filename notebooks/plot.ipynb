# %% [markdown]
# ## Scaling H in the 1-layer model

# %% [markdown]
# ### First experiment

# %% [markdown]
# First large scale experiment scaling H.

# %%
P = 6000
Hs = [100, 200, 400, 800, 1600]

train_accs_rf = [
    0.802,
    0.815,
    0.814,
    0.809,
    0.801,
]

eval_accs_rf = [
    0.817,
    0.827,
    0.824,
    0.817,
    0.809,
]

train_accs_drf = [
    0.786,
    0.787,
    0.790,
    0.796,
    0.813,
]
eval_accs_drf = [
    0.800,
    0.793,
    0.792,
    0.786,
    0.784,
]

train_accs_fl = [
    0.786,
    0.763,
    0.767,
    0.744,
    0.569,
]
eval_accs_fl = [
    0.800,
    0.776,
    0.773,
    0.740,
    0.551,
]

train_accs_fl_max = [
    0.79,
    0.81,
    0.81,
    0.83,
    0.86,
]
eval_accs_fl_max = [
    0.80,
    0.82,
    0.81,
    0.82,
    0.84,
]

import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

ax = axs[0]
ax.plot(Hs, train_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(Hs, train_accs_drf, label="Dynamic Random Features", marker="o", color="green")
ax.plot(Hs, train_accs_fl, label="Feature Learning", marker="o", color="blue")
ax.plot(
    Hs,
    train_accs_fl_max,
    label="Feature Learning (early stopping)",
    marker="o",
    color="grey",
)
ax.set_title("Train Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs)
ax.set_xticklabels(Hs)
ax.set_ylim(0.5, 1.02)
ax.grid()

ax = axs[1]
ax.plot(Hs, eval_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(Hs, eval_accs_drf, label="Dynamic Random Features", marker="o", color="green")
ax.plot(Hs, eval_accs_fl, label="Feature Learning", marker="o", color="blue")
ax.plot(
    Hs,
    eval_accs_fl_max,
    label="Feature Learning (early stopping)",
    marker="o",
    color="grey",
)
ax.set_title("Eval Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs)
ax.set_xticklabels(Hs)
ax.set_ylim(0.5, 1.02)
ax.grid()

plt.suptitle(f"Final Accuracy vs Hidden Width -- MNIST, N=100, {P} patterns per class")
plt.tight_layout()
plt.show()

# %%
P = 600
Hs = [100, 200, 400, 800, 1600]

train_accs_rf = [
    0.7941666841506958,
    0.8240000009536743,
    0.831166684627533,
    0.8301666378974915,
    0.8271666765213013,
]

eval_accs_rf = [
    0.7786666750907898,
    0.8103333115577698,
    0.8103333115577698,
    0.8033333420753479,
    0.7973333597183228,
]

train_accs_drf = [
    0.793,
    0.816,
    0.847,
    0.909,
    0.981,
]
eval_accs_drf = [
    0.782,
    0.781,
    0.766,
    0.729,
    0.691,
]

train_accs_fl = [
    0.793,
    0.844,
    0.892,
    0.960,
    0.980,
]
eval_accs_fl = [
    0.782,
    0.797,
    0.771,
    0.768,
    0.785,
]

import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

ax = axs[0]
ax.plot(Hs, train_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(Hs, train_accs_drf, label="Dynamic Random Features", marker="o", color="green")
ax.plot(Hs, train_accs_fl, label="Feature Learning", marker="o", color="blue")
ax.set_title("Train Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs)
ax.set_xticklabels(Hs)
ax.set_ylim(0.5, 1.02)
ax.grid()

ax = axs[1]
ax.plot(Hs, eval_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(Hs, eval_accs_drf, label="Dynamic Random Features", marker="o", color="green")
ax.plot(Hs, eval_accs_fl, label="Feature Learning", marker="o", color="blue")
ax.set_title("Eval Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs)
ax.set_xticklabels(Hs)
ax.set_ylim(0.5, 1.02)
ax.grid()

plt.suptitle(f"Final Accuracy vs Hidden Width -- MNIST, N=100, {P} patterns per class")
plt.tight_layout()
plt.show()

# %%
P = 60
Hs = [100, 200, 400, 800, 1600]

train_accs_rf = [
    0.781,
    0.873,
    0.939,
    0.986,
    1.0,
]

eval_accs_rf = [
    0.685,
    0.726,
    0.731,
    0.715,
    0.698,
]

train_accs_drf = [
    0.917,
    0.963,
    1.0,
    1.0,
    1.0,
]
eval_accs_drf = [
    0.701,
    0.662,
    0.619,
    0.619,
    0.646,
]

train_accs_fl = [
    0.917,
    0.967,
    0.997,
    1.0,
    0.858,
]
eval_accs_fl = [
    0.701,
    0.705,
    0.701,
    0.738,
    0.732,
]

import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

ax = axs[0]
ax.plot(Hs, train_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(Hs, train_accs_drf, label="Dynamic Random Features", marker="o", color="green")
ax.plot(Hs, train_accs_fl, label="Feature Learning", marker="o", color="blue")
ax.set_title("Train Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs)
ax.set_xticklabels(Hs)
ax.set_ylim(0.5, 1.02)
ax.grid()

ax = axs[1]
ax.plot(Hs, eval_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(Hs, eval_accs_drf, label="Dynamic Random Features", marker="o", color="green")
ax.plot(Hs, eval_accs_fl, label="Feature Learning", marker="o", color="blue")
ax.set_title("Eval Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs)
ax.set_xticklabels(Hs)
ax.set_ylim(0.5, 1.02)
ax.grid()

plt.suptitle(f"Final Accuracy vs Hidden Width -- MNIST, N=100, {P} patterns per class")
plt.tight_layout()
plt.show()

# %% [markdown]
# Osservazioni:
# - la baseline con random features sembra smettere di migliorare, e anzi peggiorare, dopo una certa H
#     - potrebbe essere un problema di learning rate? con lr piu basso, diventa monotono wrt H ma comunque in un range molto simile di train accuracy (<=83%)
# - per P=60, H=1600 (max H provato) feature learning si comporta male: molto instabile, non riesce a fittare (mentre per H piu basso fitta).
# - per P=6000, feature learning si comporta male: all'inizio sale, poi inizia a scendere.
# - differenza tra dynamic features e feature learning:
#     - P=60: training acc simile. eval acc migliore per feat learning
#     - P=600: training acc migliore per feat learning (ma recuperato a H=1600), eval acc migliore per feat learning
#     - P=6000: dynamic features è stabile e la sua accuracy è monotona nel tempo (circa), feature learning ha problemi. La max accuacy raggiunta è migliore per feat learning, sia train sia eval.
# - riusciamo a fittare? nel caso P=6000, consideriamo solo il periodo iniziale di stabilità e crescita monotona dell'accuracy.
#     - in tutti i casi le performance migliorano con H.
#     - per P=60,600 riusciamo a ottenere un fit quasi perfetto con H abbastanza grande.
#     - per P=6000, H=1600 ancora non basta a fittare (86% max train acc).

# %% [markdown]
# ### Second Experiment

# %% [markdown]
# Improved hyperparams wrt first

# %%
import pandas as pd

P = 6000
Hs = [100, 200, 400, 800, 1600, 3200]
Hs_long = [100, 200, 400, 800, 1600, 3200, 6400]

df = pd.read_csv(
    "../multirun/single-layer/feature-learning/2025-05-07-12-34-06/cfg:data.P=6000/grid_search_results.csv"
)
assert all(i in Hs_long for i in df["H"].values)
train_accs_fl_long = df["max_train_acc"].values
eval_accs_fl_long = df["max_eval_acc"].values

df = pd.read_csv(
    "../multirun/single-layer/feature-learning/2025-05-06-17-34-47/cfg:data.P=6000/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_fl = df["max_train_acc"].values
eval_accs_fl = df["max_eval_acc"].values

df = pd.read_csv(
    "../multirun/single-layer/dynamic-features/2025-05-06-19-24-26/cfg:data.P=6000/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_drf = df["max_train_acc"].values
eval_accs_drf = df["max_eval_acc"].values

train_accs_rf = [0.7817, 0.81, 0.82, 0.84, 0.86, 0.88]
eval_accs_rf = [0.7919, 0.82, 0.83, 0.84, 0.86, 0.88]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
ax = axs[0]
ax.plot(Hs, train_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    train_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    train_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
ax.plot(
    Hs_long,
    train_accs_fl_long,
    label="Feature Learning (long)",
    marker="o",
    color="grey",
)
ax.set_title("Train Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
# ax.set_xscale("log")
ax.grid()

ax = axs[1]
ax.plot(Hs, eval_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    eval_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    eval_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
ax.plot(
    Hs_long,
    eval_accs_fl_long,
    label="Feature Learning (long)",
    marker="o",
    color="grey",
)
ax.set_title("Eval Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
# ax.set_xscale("log")
ax.grid()

plt.suptitle(
    f"Final Accuracy vs Hidden Width -- binarized MNIST, N=100, {P} patterns per class"
)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

P = 600
Hs = [100, 200, 400, 800, 1600, 3200]
Hs_long = [100, 200, 400, 800, 1600, 3200, 6400]

df = pd.read_csv(
    "../multirun/single-layer/feature-learning/2025-05-07-15-22-58/cfg:data.P=600/grid_search_results.csv"
)
assert all(i in Hs_long for i in df["H"].values)
train_accs_fl_long = df["max_train_acc"].values
eval_accs_fl_long = df["max_eval_acc"].values

df = pd.read_csv(
    "../multirun/single-layer/feature-learning/2025-05-06-17-34-47/cfg:data.P=600/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_fl = df["max_train_acc"].values
eval_accs_fl = df["max_eval_acc"].values

df = pd.read_csv(
    "../multirun/single-layer/dynamic-features/2025-05-06-19-24-26/cfg:data.P=600/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_drf = df["max_train_acc"].values
eval_accs_drf = df["max_eval_acc"].values

train_accs_rf = [0.739, 0.79, 0.82, 0.83, 0.84, 0.85]
eval_accs_rf = [0.735, 0.78, 0.81, 0.81, 0.82, 0.81]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
ax = axs[0]
ax.plot(Hs, train_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    train_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    train_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
ax.plot(
    Hs_long,
    train_accs_fl_long,
    label="Feature Learning (long)",
    marker="o",
    color="grey",
)
ax.set_title("Train Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
# ax.set_xscale("log")
ax.grid()

ax = axs[1]
ax.plot(Hs, eval_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    eval_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    eval_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
ax.plot(
    Hs_long,
    eval_accs_fl_long,
    label="Feature Learning (long)",
    marker="o",
    color="grey",
)
ax.set_title("Eval Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
# ax.set_xscale("log")
ax.grid()

plt.suptitle(
    f"Final Accuracy vs Hidden Width -- binarized MNIST, N=100, {P} patterns per class"
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Osservazioni:
# - la baseline random features non mi convince fino in fondo...
# - va tutto alla grande!
#     - meglio delle baseline a parità di epoche
#     - fittiamo tutto benissimo asintoticamente
#     - generalizziamo anche benino

# %% [markdown]
# ### Third Experiment

# %% [markdown]
# Tuned better the baseline, and made a more fair comparison by bringing every method to our framework.

# %%
import pandas as pd

P = 6000
Hs = [100, 200, 400, 800, 1600, 3200, 6400]
Hs_long = [100, 200, 400, 800, 1600, 3200, 6400]

# df = pd.read_csv(
#     "../multirun/single-layer/feature-learning/2025-05-07-12-34-06/cfg:data.P=6000/grid_search_results.csv"
# )
# assert all(i in Hs_long for i in df["H"].values)
# train_accs_fl_long = df["max_train_acc"].values
# eval_accs_fl_long = df["max_eval_acc"].values

df = pd.read_csv(
    f"../multirun/single-layer/feature-learning/2025-05-08-19-25-04/cfg:data.P={P},lambda_wback=1.0,lr=[0.03,0.0,0.1],symmetric_W=buggy/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_fl = df["max_train_acc"].values
eval_accs_fl = df["max_eval_acc"].values

df = pd.read_csv(
    f"../multirun/single-layer/dynamic-features/2025-05-08-18-21-55/cfg:data.P={P},lambda_wback=0.0,lr=[0.0,0.0,0.1],symmetric_W=False/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_drf = df["max_train_acc"].values
eval_accs_drf = df["max_eval_acc"].values

df = pd.read_csv(
    f"../multirun/single-layer/random-features/2025-05-08-18-25-28/cfg:data.P={P},init_mode=zeros,lambda_wback=0.0,lr=[0.0,0.0,0.1],max_steps=2,symmetric_W=False/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_rf = df["max_train_acc"].values
eval_accs_rf = df["max_eval_acc"].values

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
ax = axs[0]
ax.plot(Hs, train_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    train_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    train_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
# ax.plot(
#     Hs_long,
#     train_accs_fl_long,
#     label="Feature Learning (long)",
#     marker="o",
#     color="grey",
# )
ax.set_title("Train Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
ax.set_xscale("log")
ax.grid()

ax = axs[1]
ax.plot(Hs, eval_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    eval_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    eval_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
# ax.plot(
#     Hs_long,
#     eval_accs_fl_long,
#     label="Feature Learning (long)",
#     marker="o",
#     color="grey",
# )
ax.set_title("Eval Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
ax.set_xscale("log")
ax.grid()

plt.suptitle(
    f"Final Accuracy vs Hidden Width -- binarized MNIST, N=100, {P} patterns per class"
)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

P = 600
Hs = [100, 200, 400, 800, 1600, 3200, 6400]
Hs_long = [100, 200, 400, 800, 1600, 3200, 6400]

# df = pd.read_csv(
#     "../multirun/single-layer/feature-learning/2025-05-07-12-34-06/cfg:data.P=6000/grid_search_results.csv"
# )
# assert all(i in Hs_long for i in df["H"].values)
# train_accs_fl_long = df["max_train_acc"].values
# eval_accs_fl_long = df["max_eval_acc"].values

df = pd.read_csv(
    f"../multirun/single-layer/feature-learning/2025-05-08-19-25-04/cfg:data.P={P},lambda_wback=1.0,lr=[0.03,0.0,0.1],symmetric_W=buggy/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_fl = df["max_train_acc"].values
eval_accs_fl = df["max_eval_acc"].values

df = pd.read_csv(
    f"../multirun/single-layer/dynamic-features/2025-05-08-18-21-55/cfg:data.P={P},lambda_wback=0.0,lr=[0.0,0.0,0.1],symmetric_W=False/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_drf = df["max_train_acc"].values
eval_accs_drf = df["max_eval_acc"].values

df = pd.read_csv(
    f"../multirun/single-layer/random-features/2025-05-08-18-25-28/cfg:data.P={P},init_mode=zeros,lambda_wback=0.0,lr=[0.0,0.0,0.1],max_steps=2,symmetric_W=False/grid_search_results.csv"
)
assert all(i in Hs for i in df["H"].values)
train_accs_rf = df["max_train_acc"].values
eval_accs_rf = df["max_eval_acc"].values

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
ax = axs[0]
ax.plot(Hs, train_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    train_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    train_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
# ax.plot(
#     Hs_long,
#     train_accs_fl_long,
#     label="Feature Learning (long)",
#     marker="o",
#     color="grey",
# )
ax.set_title("Train Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
ax.set_xscale("log")
ax.grid()

ax = axs[1]
ax.plot(Hs, eval_accs_rf, label="Random Features", marker="o", color="black")
ax.plot(
    Hs,
    eval_accs_drf,
    label="Reservoir",
    marker="o",
    color="green",
)
ax.plot(
    Hs,
    eval_accs_fl,
    label="Feature Learning",
    marker="o",
    color="blue",
)
# ax.plot(
#     Hs_long,
#     eval_accs_fl_long,
#     label="Feature Learning (long)",
#     marker="o",
#     color="grey",
# )
ax.set_title("Eval Accuracy")
ax.set_xlabel("Hidden Width")
ax.set_ylabel("Accuracy")
ax.legend()
ax.set_xticks(Hs_long)
ax.set_xticklabels(Hs_long)
ax.set_ylim(0.5, 1.02)
ax.set_xscale("log")
ax.grid()

plt.suptitle(
    f"Final Accuracy vs Hidden Width -- binarized MNIST, N=100, {P} patterns per class"
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Experiment 4

# %% [markdown]
# Here, I tuned the parameters and especially focused attention on J_D, which had shown to control a trade off between fitting and generalization. I let the robustness threshold scale additively with J_D [Actually, I have not done that. I thought I had. Bug with config... So, in truth, threshold was smaller than I had intended already for J_D = 0.3 (0.7 instead of 1.0), and it gets worse with increasing J_D].

# %%
# Read results and put them in a single dataframe
import pandas as pd

df = pd.read_csv(
    "../multirun/single-layer/feature-learning/2025-05-14-06-27-21/cfg:+H_values=[100,200,400,800,1600,3200,6400],+J_D_values=[0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7],data.P=6000,lambda_wback=1.0,lr=[0.03,0.0,0.1],symmetric_W=buggy,threshold_readout=3.0,weight_decay_J=0.005/grid_search_results.csv"
)
df2 = pd.read_csv(
    "../multirun/single-layer/feature-learning/2025-05-14-12-50-26/cfg:+H_values=[100,200,400,800,1600,3200,6400],+J_D_values=[0.7,0.65,0.6,0.55,0.5,0.45,0.4,0.35,0.3],data.P=6000,lambda_wback=1.0,lr=[0.03,0.0,0.1],symmetric_W=buggy,threshold_readout=3.0,weight_decay_J=0.005/grid_search_results.csv"
)
J_Ds = [0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7]
for jd in J_Ds:
    if jd not in df["J_D"].values:
        assert jd in df2["J_D"].values
        df = pd.concat([df, df2[df2["J_D"] == jd]])

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# Aesthetic defaults
plt.rcParams.update(
    {
        "font.size": 12,  # base font size
        "axes.titlesize": 14,
        "axes.labelsize": 13,
        "legend.fontsize": 11,
        "xtick.direction": "out",
        "ytick.direction": "out",
        "axes.spines.top": False,  # remove top/right spines
        "axes.spines.right": False,
    }
)

# Prepare data
jds = sorted(df["J_D"].unique())
cmap = cm.get_cmap("viridis", len(jds))

# Create subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5), sharex=True, sharey=False)

for idx, j in enumerate(jds):
    sub = df[df["J_D"] == j].sort_values("H")
    color = cmap(idx)
    for ax, col in zip((ax1, ax2), ("max_train_acc", "max_eval_acc")):
        ax.plot(
            sub["H"],
            sub[col],
            label=f"{j:.2f}",
            color=color,
            marker="^",  # triangle marker
            markersize=6,
            linestyle="--",  # dotted line
            linewidth=1,
        )

# Labels & titles
ax1.set(title="Train Accuracy", xlabel="H", ylabel="Accuracy")
ax2.set(title="Eval Accuracy", xlabel="H")

# Legend outside
ax2.legend(title="$J_D$", loc="upper left", bbox_to_anchor=(1.02, 1), frameon=False)

# Log-scaled x-axis
for ax in (ax1, ax2):
    # ax.set_xscale("log")
    ax.grid(True, which="both", linestyle="--", linewidth=0.5)  # subtle grid
    # ax.set_xticks(df["H"].unique())
    # ax.set_xticklabels(df["H"].unique())
    ax.set_xlabel("Hidden Width")

fig.suptitle("Accuracy vs Hidden Width - Entangled MNIST, N=100")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/jy/x5558th97mjgtzp6f33ryf840000gn/T/ipykernel_46608/3288502163.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("viridis", len(jds))

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

# assume 'df' is already loaded with columns ['J_D','H','max_train_acc','max_eval_acc']
P = 6000
Hs = [100, 200, 400, 800, 1600, 3200, 6400]

# — load old data —
df_drf = pd.read_csv(
    f"../multirun/single-layer/dynamic-features/2025-05-08-18-21-55/"
    f"cfg:data.P={P},lambda_wback=0.0,lr=[0.0,0.0,0.1],symmetric_W=False/"
    "grid_search_results.csv"
)
train_accs_drf = df_drf["max_train_acc"].values
eval_accs_drf = df_drf["max_eval_acc"].values

df_rf = pd.read_csv(
    f"../multirun/single-layer/random-features/2025-05-08-18-25-28/"
    f"cfg:data.P={P},init_mode=zeros,lambda_wback=0.0,lr=[0.0,0.0,0.1],"
    "max_steps=2,symmetric_W=False/grid_search_results.csv"
)
train_accs_rf = df_rf["max_train_acc"].values
eval_accs_rf = df_rf["max_eval_acc"].values

df_fl = pd.read_csv(
    f"../multirun/single-layer/feature-learning/2025-05-08-19-25-04/cfg:data.P={P},lambda_wback=1.0,lr=[0.03,0.0,0.1],symmetric_W=buggy/grid_search_results.csv"
)
train_accs_fl = df_fl["max_train_acc"].values
eval_accs_fl = df_fl["max_eval_acc"].values

# — select which J_D curves to plot —
selected_jds = [0.5]
colors = ["red", "orange", "yellow"]
jds = sorted(selected_jds)
cmap = cm.get_cmap("hot", len(jds))

# — make subplots —
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharex=True)

# new data (selected J_D)
for i, j in enumerate(jds):
    sub = df[df["J_D"] == j].sort_values("H")
    ax1.plot(
        sub["H"],
        sub["max_train_acc"],
        label=f"feature-learning (new, J_D={j})",
        color=colors[i],
        marker="o",
    )
    ax2.plot(
        sub["H"],
        sub["max_eval_acc"],
        label=f"feature-learning (new, J_D={j})",
        color=colors[i],
        marker="o",
    )

# old series
ax1.plot(Hs, train_accs_drf, label="reservoir", color="green", marker="o")
ax1.plot(Hs, train_accs_rf, label="random-features", color="black", marker="o")
ax1.plot(Hs, train_accs_fl, label="feature-learning (old)", color="blue", marker="o")
ax2.plot(Hs, eval_accs_drf, label="reservoir", color="green", marker="o")
ax2.plot(Hs, eval_accs_rf, label="random-features", color="black", marker="o")
ax2.plot(Hs, eval_accs_fl, label="feature-learning (old)", color="blue", marker="o")

# labels, titles, legends
ax1.set(xlabel="H", title="Train Accuracy")
ax2.set(xlabel="H", title="Eval Accuracy")
for ax in (ax1, ax2):
    ax.set_ylabel("Accuracy")
    ax.set_xticks(Hs)
    ax.set_xticklabels(Hs)
    ax.grid()
    ax.set_xscale("log")
    ax.legend(loc="best")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/jy/x5558th97mjgtzp6f33ryf840000gn/T/ipykernel_46608/2624525037.py:36: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("hot", len(jds))

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm

# Aesthetic defaults
plt.rcParams.update(
    {
        "font.size": 12,
        "axes.titlesize": 14,
        "axes.labelsize": 13,
        "legend.fontsize": 11,
        "xtick.direction": "out",
        "ytick.direction": "out",
        "axes.spines.top": False,
        "axes.spines.right": False,
    }
)

# Load data
P = 6000
Hs = [100, 200, 400, 800, 1600, 3200, 6400]

df_drf = pd.read_csv(
    f"../multirun/single-layer/dynamic-features/2025-05-08-18-21-55/"
    f"cfg:data.P={P},lambda_wback=0.0,lr=[0.0,0.0,0.1],symmetric_W=False/"
    "grid_search_results.csv"
)
df_rf = pd.read_csv(
    f"../multirun/single-layer/random-features/2025-05-08-18-25-28/"
    f"cfg:data.P={P},init_mode=zeros,lambda_wback=0.0,lr=[0.0,0.0,0.1],"
    "max_steps=2,symmetric_W=False/grid_search_results.csv"
)
df_fl = pd.read_csv(
    f"../multirun/single-layer/feature-learning/2025-05-08-19-25-04/"
    f"cfg:data.P={P},lambda_wback=1.0,lr=[0.03,0.0,0.1],symmetric_W=buggy/"
    "grid_search_results.csv"
)

# pick new J_D curves
# selected_jds = [0.3, 0.7]
# colors_new = ["red"]
# df_new = df[df["J_D"].isin(selected_jds)]

# Subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharex=True)

# # Plot new (feature-learning) series
# for color, j in zip(colors_new, selected_jds):
#     sub = df_new[df_new["J_D"] == j].sort_values("H")
#     ax1.plot(
#         sub["H"],
#         sub["max_train_acc"],
#         label=f"feat. learning",
#         color=color,
#         marker="^",
#         linestyle="--",
#         markersize=6,
#         linewidth=1,
#     )
#     ax2.plot(
#         sub["H"],
#         sub["max_eval_acc"],
#         label=f"feat. learning",
#         color=color,
#         marker="^",
#         linestyle="--",
#         markersize=6,
#         linewidth=1,
#     )

# Plot old series
data = [
    (
        df_new[df_new["J_D"] == 0.7].sort_values("H")["max_train_acc"],
        df_new[df_new["J_D"] == 0.3].sort_values("H")["max_eval_acc"],
        "feat. learning",
        "red",
    ),
    (df_rf["max_train_acc"], df_rf["max_eval_acc"], "random feat.", "black"),
    (df_drf["max_train_acc"], df_drf["max_eval_acc"], "reservoir", "green"),
    # (df_fl["max_train_acc"], df_fl["max_eval_acc"], "old FL", "blue"),
]
for train_accs, eval_accs, label, color in data:
    ax1.plot(
        Hs,
        train_accs,
        label=label,
        color=color,
        marker="^",
        linestyle="--",
        markersize=6,
        linewidth=1,
    )
    ax2.plot(
        Hs,
        eval_accs,
        label=label,
        color=color,
        marker="^",
        linestyle="--",
        markersize=6,
        linewidth=1,
    )

# Labels & titles
ax1.set(xlabel="H", ylabel="Accuracy", title="Train Accuracy")
ax2.set(xlabel="H", title="Eval Accuracy")

# Formatting
for ax in (ax1, ax2):
    # ax.set_xscale("log")
    # ax.set_xticks(Hs)
    # ax.set_xticklabels(Hs)
    ax.grid(True, which="both", linestyle="--", linewidth=0.5)
    ax.legend(loc="best", frameon=False)
    ax.set_xlabel("Hidden Width")

fig.suptitle("Accuracy vs Hidden Width - Entangled MNIST, N=100")
plt.tight_layout()
plt.show()
